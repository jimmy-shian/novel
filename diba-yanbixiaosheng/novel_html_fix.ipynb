# %% [markdown]
# # Python 爬蟲實戰範例｜學會抓取 Yahoo奇摩最新電影
# 提供給想學習 Python 爬蟲的朋友們，分享 Python 爬蟲的步驟與方法，並提供完整的程式碼，只要常透過不同主題的實戰練習，就可以駕輕就熟爬蟲技術，往後要抓取網頁資料，就能夠輕易上手
#
# 網站文章：https://www.webscrapingpro.tw/yahoo-movie-web-scraping-using-python/

# %%
import requests
import numpy as np
import re
import time
from bs4 import BeautifulSoup

# %% [markdown]
# # chatch novel from internet

# %%
def add_html_title_first(file,title_all):
    filename = file
    with open(filename, 'w', encoding='utf-8') as f:
        # content = f.read()
        f.seek(0, 0)
        text = f'{title_all}'
        f.write(str('<title>') + text + str('</title>'))
        f.seek(0, 1)
        text = f'{title_all}'
        f.write(str('<br>') + str('<center>') + text + str('</center>') + str('<br>'))

# %%
def catch_title(a):
    url = '帝霸_html' + str(a) + '.html'
    with open(url, encoding='UTF-8') as file:
        # 解析HTML
        soup = BeautifulSoup(file, "lxml")
        
        # 查找 title 標籤
        title = soup.find("title")
        if title:
            title_text = title.text
        else:
            title_text = "No title found"

    return str(title_text)
# def catch_title(a):
#     url = '帝霸_html' + str(a) + '.html'
#     with open(url, encoding='UTF-8') as file:
#         # 解析HTML
#         soup = BeautifulSoup(file, "lxml")
#         # 查找 title 標籤
#         title = soup.find("title").text
#         name_url = title + url 
#     return title

# %%
def add_txt_title(file,title_all):
    filename = file
    with open(filename, 'r+', encoding='utf-8') as f:
        content = f.read()
        f.seek(0, 0)
        text = f'{title_all}'
        f.write(str('<br>') + str('<title>') + text + str('</title>') + str('<br>') + content)
     

        
def add_html_title(file, title_all, a):
    filename = file
    
    with open(filename, 'r', encoding='utf-8') as f:
      CONTENT = f.read()
    link = '帝霸_html' + str(a) + '.html'
    add_html_title_first(link, title_all)

    with open(filename, 'w+', encoding='utf-8') as f:
      content = f.read()
      f.seek(0, 0)
      text = f'{title_all}'
      f.write(
        f'''<!doctype html>
      <html lang="en">
        <head>
          <!-- Required meta tags -->
          <meta charset="utf-8">
          <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">

          <!-- Bootstrap CSS -->
          <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0/dist/css/bootstrap.min.css" rel="stylesheet" integrity="sha384-wEmeIV1mKuiNpC+IOBjI7aAzPcEZeedi5yW5f2yOq55WWLwNGmvvx4Um1vskeMj0" crossorigin="anonymous">
          <link rel="stylesheet" type="text/css" href="novel.css">
          
          <title>{text}</title>
        </head>
        <body>
          <script data-ad-client="ca-pub-2415998114933157" async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
          
          <nav class="navbar navbar-expand-lg navbar-dark bg-dark">
              <div class="container-fluid">
                <a class="navbar-brand" href="">My novel site</a>
                <button class="navbar-toggler" type="button" data-bs-toggle="collapse" data-bs-target="#navbarNav" aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation">
                  <span class="navbar-toggler-icon"></span>
                </button>
                <div class="collapse navbar-collapse" id="navbarNav">
                  <ul class="navbar-nav">
                    <li class="nav-item">
                      <a class="nav-link" href="../index.html">Home</a>
                    </li>
                    <li class="nav-item">
                      <a class="nav-link" href="diba-yanbixiaosheng.html">帝霸</a>
                    </li>
                    <li class="nav-item">
                      <a class="nav-link" href="../index.html">Pricing</a>
                    </li>
                  </ul>
                </div>
              </div>
            </nav>        
      '''    )
      try:
        f.seek(0, 1)
        text = f'{catch_title(a-1)}'
        linka_1 = '帝霸_html' + str(a-1) + '.html'
        f.write(
          f'''      <div class='responsive-div'>
        <div class="container">
          <img src="../picture/帝霸封面.jpg" alt="{text}">
          <div class="text">
            <a href="{linka_1}" class="link">回上一章 : {text}</a>
          </div>
        </div>
          '''
                )
      except FileNotFoundError:
        f.seek(0, 1)
        # text = f'{catch_title(a-1)}'
        f.write(
          '''      <div class='responsive-div'>
        <div class="container">
          <img src="../picture/cover.jpg" alt="your-image-alt">
          <div class="text">
            <a href="../index.html" class="link">回主畫面</a>
          </div>
        </div>
          ''')
        
      content = f.read()
      f.seek(0, 1)
      text = f'{title_all}'
      f.write(str('<br>') + str('<center>') + text + str('</center>') + str('<br>') + CONTENT)
      
      try:
        f.seek(0, 2)
        text = f'{catch_title(a-1)}'
        linka_1 = '帝霸_html' + str(a-1) + '.html'
        f.write(
          f'''  
        <div class="container">
          <img src="../picture/帝霸封面.jpg" alt="{text}">
          <div class="text">
            <a href="{linka_1}" class="link">回上一章 : {text}</a>
          </div>
        </div>
          '''
                )
      except FileNotFoundError:
        f.seek(0, 2)
        # text = f'{catch_title(a-1)}'
        f.write(
          '''
        <div class="container">
          <img src="../picture/cover.jpg" alt="your-image-alt">
          <div class="text">
            <a href="../index.html" class="link">回主畫面</a>
          </div>
        </div>
          '''
                )
      try:  
        f.seek(0, 1)
        text = f'{catch_title(a+1)}'  #a+1
        linka1 = '帝霸_html' + str(a+1) + '.html'
        f.write(
          f'''
          <div class="container">
            <img src="../picture/帝霸封面.jpg" alt="{text}">
            <div class="text">
              <a href="{linka1}" class="link">往下一章 : {text}</a>
            </div>
          </div>
        </div>
            '''
                )
      except FileNotFoundError:
        f.seek(0, 1)
        # text = f'{catch_title(a-1)}'
        f.write(
          '''
        <div class="container">
          <img src="../picture/cover.jpg" alt="your-image-alt">
          <div class="text">
            <a href="../index.html" class="link">回主畫面</a>
          </div>
        </div>
          '''
                )
        
      f.seek(0, 1)
      f.write(
            """    <script>
        window.onload = function() {
        var iframe = document.getElementById("iframe");
        var prevScroll = localStorage.getItem("prevScroll");
        if (prevScroll) {
        iframe.contentWindow.scrollTo(0, prevScroll);
        }
        iframe.onload = function() {
        localStorage.setItem("prevScroll", iframe.contentWindow.pageYOffset);
        };
        };
        </script>
        <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.bundle.min.js" integrity="sha384-MrcW6ZMFYlzcLA8Nl+NtUVF0sA7MsXsP1UyJoMp4YLEuNSfAP+JcXn/tWtIaxVXM" crossorigin="anonymous"></script> </body>
        </html>
          """)
      f.close()

# %%
def catch(soup_url, a):
    title = str(soup_url.find('div', 'title'))

    # title_name = str(soup_url.find('div', 'prev_page'))
    title_name = str('《帝霸》▷ ')
    info_items = soup_url.find_all('p')
    
    txt_list = []
    html_list = []

    title = re.sub(r'<.*?>',"",title)
    title_name = re.sub(r'<.*?>', " ", re.sub(r'\W\w*章', " ", title_name))
    title_all = title_name + title
    # title_name = re.sub(r'<.*?>', "", title_name) # title_name = re.sub(r'\B\D\W\w*章', "", title_name)
    # print(title_all)

    for item in info_items:

        txt_item = item.text.strip()
        html = str('<br>') + str('&emsp;&emsp;') + str(txt_item) + str('<br>')
        use = []
        # if len(txt_item)+2>40:
        #     k = 0
        #     for i in range(0, int(len(txt_item)/40)+1):
        #         use = txt_item[k:(i+1)*40]
        #         k = k + 40
        #         if i == 0:
        #             txt_list.append(f'\n    {use}')
        #         else:
        #             txt_list.append(f'\n{use}')
        # else:
        #     txt_list.append(f'\n    {txt_item}')
            
        html_list.append(f'{html}')


    # np.savetxt('帝霸' + str(a) + '.txt', txt_list, fmt='%s', delimiter=',', encoding='UTF-8')
    np.savetxt('帝霸_html' + str(a) + '.html', html_list, fmt='%s', delimiter=',', encoding='UTF-8')
    np.savetxt('帝霸_html' + str(a) + '.txt', html_list, fmt='%s', delimiter=',', encoding='UTF-8')
    
    
    # add_html_title_first('帝霸_html' + str(a+1) + '.html',title_all)

    add_txt_title('帝霸_html' + str(a) + '.txt',title_all)
    add_html_title('帝霸_html' + str(a) + '.html', title_all, a)

# %% [markdown]
# ## Working program

# %%
for a in range(5353,5357): #5353
    url = 'https://www.bg3.co/novel/pagea/diba-yanbixiaosheng_' + str(a) + '.html'
    if a%150 == 0:
        print(url)
    response = requests.get(url=url)
    soup = BeautifulSoup(response.text, 'lxml')
    catch(soup, a)
    time.sleep(1)

# %% [markdown]
# # change html from local

# %% [markdown]
# ## creat body_head of html

# %%
def catch_title(a):
    url = '帝霸_html' + str(a) + '.html'
    with open(url, encoding='UTF-8') as file:
        # 解析HTML
        soup = BeautifulSoup(file, "lxml")
        # 查找 title 標籤
        title = soup.find("title")
        if title:
            title_text = title.text
        else:
            title_text = "No title found"

    return str(title_text)

# %%
def add_html_body_head(file, title_all, a):
    filename = file
    txt_file = '帝霸_html' + str(a) + '.txt'
    with open(txt_file, 'r', encoding='utf-8') as f:
      CONTENT = f.read()
      
    link = '帝霸_html' + str(a) + '.html'
    # catch_title(a)
    with open(filename, 'w+', encoding='utf-8') as f:
      content = f.read()
      f.seek(0, 0)
      text = f'{title_all}'
      f.write(
        f'''<!doctype html>
      <html lang="en">
        <head>
          <!-- Required meta tags -->
          <meta charset="utf-8">
          <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">

          <!-- Bootstrap CSS -->
          <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0/dist/css/bootstrap.min.css" rel="stylesheet" integrity="sha384-wEmeIV1mKuiNpC+IOBjI7aAzPcEZeedi5yW5f2yOq55WWLwNGmvvx4Um1vskeMj0" crossorigin="anonymous">
          <link rel="stylesheet" type="text/css" href="novel.css">
          
          <title>{text}</title>
        </head>
        <body>
          <script data-ad-client="ca-pub-2415998114933157" async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
          
          <nav class="navbar navbar-expand-lg navbar-dark bg-dark">
              <div class="container-fluid">
                <a class="navbar-brand" href="">My novel site</a>
                <button class="navbar-toggler" type="button" data-bs-toggle="collapse" data-bs-target="#navbarNav" aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation">
                  <span class="navbar-toggler-icon"></span>
                </button>
                <div class="collapse navbar-collapse" id="navbarNav">
                  <ul class="navbar-nav">
                    <li class="nav-item">
                      <a class="nav-link" href="../index.html">Home</a>
                    </li>
                    <li class="nav-item">
                      <a class="nav-link" href="diba-yanbixiaosheng.html">帝霸</a>
                    </li>
                    <li class="nav-item">
                      <a class="nav-link" href="../index.html">Pricing</a>
                    </li>
                  </ul>
                </div>
              </div>
            </nav>        
      '''    )
      try:
        f.seek(0, 1)
        text = f'{catch_title(a-1)}'
        linka_1 = '帝霸_html' + str(a-1) + '.html'
        f.write(
          f'''    <div class="spacer"></div>
      <div class='responsive-div'>
        <div class="container">
          <img src="../picture/帝霸封面.jpg" alt="{text}">
          <div class="text">
            <a href="{linka_1}" class="link">回上一章 : {text}</a>
          </div>
        </div>
          '''
                )
      except FileNotFoundError:
        f.seek(0, 1)
        # text = f'{catch_title(a-1)}'
        f.write(
          '''    <div class="spacer"></div>
      <div class='responsive-div'>
        <div class="container">
          <img src="../picture/cover.jpg" alt="your-image-alt">
          <div class="text">
            <a href="../index.html" class="link">回主畫面</a>
          </div>
        </div>
          ''')

      f.seek(0, 1)
      text = f'{title_all}'
      f.write(str('<br>') + str('<center>') + text + str('</center>') + str('<br>') + CONTENT)
      
      try:
        f.seek(0, 2)
        text = f'{catch_title(a-1)}'
        linka_1 = '帝霸_html' + str(a-1) + '.html'
        f.write(
          f'''    <div class="spacer"></div>
  
        <div class="container">
          <img src="../picture/帝霸封面.jpg" alt="{text}">
          <div class="text">
            <a href="{linka_1}" class="link">回上一章 : {text}</a>
          </div>
        </div>
          '''
                )
      except FileNotFoundError:
        f.seek(0, 2)
        # text = f'{catch_title(a-1)}'
        f.write(
          '''    <div class="spacer"></div>
        <div class="container">
          <img src="../picture/cover.jpg" alt="your-image-alt">
          <div class="text">
            <a href="../index.html" class="link">回主畫面</a>
          </div>
        </div>
          '''
                )
      try:  
        f.seek(0, 1)
        text = f'{catch_title(a+1)}'  #a+1
        linka1 = '帝霸_html' + str(a+1) + '.html'
        f.write(
          f'''<br>
          <div class="container">
            <img src="../picture/帝霸封面.jpg" alt="{text}">
            <div class="text">
              <a href="{linka1}" class="link">往下一章 : {text}</a>
            </div>
          </div>
        </div>
            '''
                )
      except FileNotFoundError:
        f.seek(0, 1)
        # text = f'{catch_title(a-1)}'
        f.write(
          '''<br>
        <div class="container">
          <img src="../picture/cover.jpg" alt="your-image-alt">
          <div class="text">
            <a href="../index.html" class="link">回主畫面</a>
          </div>
        </div>
          '''
                )
        
      f.seek(0, 1)
      f.write(
            """     <div class="spacer"></div>
      <div class="spacer"></div>

        <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.bundle.min.js" integrity="sha384-MrcW6ZMFYlzcLA8Nl+NtUVF0sA7MsXsP1UyJoMp4YLEuNSfAP+JcXn/tWtIaxVXM" crossorigin="anonymous"></script> 
      </body>
    </html>
          
          """)

# %% [markdown]
# ## Working program

# %%
for a in range(1,5357): #5353
    if a%150 == 0:
        print(a)
    title_all = catch_title(a)
    add_html_body_head('帝霸_html' + str(a) + '.html', title_all, a)
# Out:
# 150
# 300
# 450
# 600
# 750
# 900
# 1050
# 1200
# 1350
# 1500
# 1650
# 1800
# 1950
# 2100
# 2250
# 2400
# 2550
# 2700
# 2850
# 3000
# 3150
# 3300
# 3450
# 3600
# 3750
# 3900
# 4050
# 4200
# 4350
# 4500
# 4650
# 4800
# 4950
# 5100
# 5250

# %% [markdown]
# # 完整的程式碼如下

# %%
# import csv
# import requests
# from bs4 import BeautifulSoup

# url = 'https://movies.yahoo.com.tw/movie_thisweek.html'
# response = requests.get(url=url)

# soup = BeautifulSoup(response.text, 'lxml')

# info_items = soup.find_all('div', 'release_info')

# with open('本週新片.csv', 'w', encoding='utf-8-sig', newline='') as csv_file:
    
#     csv_writer = csv.writer(csv_file)
#     fieldnames = ['電影片名', '電影英文片名', '上映時間', '網友期待度']
#     csv_writer.writerow(fieldnames)

#     for item in info_items:

#         name = item.find('div', 'release_movie_name').a.text.strip()
#         english_name = item.find('div', 'en').a.text.strip()
#         release_time = item.find('div', 'release_movie_time').text.split('：')[-1].strip()
#         level = item.find('div', 'leveltext').span.text.strip()
        
#         csv_writer.writerow([name, english_name, release_time, level])
#         print('{}({}) 上映日：{} 期待度：{}'.format(name, english_name, release_time, level))
